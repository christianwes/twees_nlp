# %% [markdown]
# # **Proyecto NLP - Deteccion de tweets con contenido de tipo racista/sexista**
#
# En el presente proyecto se utilizará un dataset que consta de tweets en idioma inglés con una etiqueta 0 / 1 que indica si un tweet es racista/sexista (1) o su temática no lo es (0)
#
# Se proponen 2 modelos para determinar la etiqueta de un tweet a partir de las palabras que lo conforman: Clasificador Bayesiano y LSTM
#
# Link al dataset: <a href="https://www.kaggle.com/arkhoshghalb/twitter-sentiment-analysis-hatred-speech/version/1?select=train.csv">Kaggle-Twitter</a>
#
# *Podrá encontrar este proyecto junto con otros de ML en mi <a href="https://github.com/christianwes/proyectos_machine_learning">Github</a>*

# %% [markdown]
# ## 1) Paquetes
# Las siguientes celdas instalan el paquete wordcloud y descargaremos los datos que utilizaremos de la librería nltk.

# %%
# !python -m pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.7/dist-packages (1.5.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from wordcloud) (7.1.2)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from wordcloud) (1.19.5)

# %%
# !python -m nltk.downloader all
# Out:
# /usr/lib/python3.7/runpy.py:125: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to /root/nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to /root/nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to /root/nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to /root/nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package floresta to /root/nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to /root/nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to /root/nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to /root/nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to /root/nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to /root/nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to /root/nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to /root/nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to /root/nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to /root/nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to /root/nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to /root/nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to /root/nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to /root/nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to /root/nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to /root/nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to /root/nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to /root/nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to /root/nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package qc to /root/nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to /root/nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to /root/nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to /root/nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to /root/nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to /root/nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to /root/nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to /root/nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to /root/nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to /root/nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all

# %%
#Importamos las librerias necesarias
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import nltk

from nltk.corpus import stopwords
from nltk.classify import SklearnClassifier
from wordcloud import WordCloud,STOPWORDS
from subprocess import check_output
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %% [markdown]
# # 2) Dataset a utilizar
#
# Subiremos el dataset y lo trabajaremos como un dataframe mediante la libreria pandas

# %%
df = pd.read_csv('tweets.csv')

# %%
# Tamaño del dataframe
df.shape
# Out:
# (31962, 3)

# %%
# Por fines demostrativos y reduccion del tiempo  de procesamiento, nos limitaremos a utilizar 5000 filas únicamente
df=df.iloc[:5000]

# %%
# Revisamos las dimensiones del dataset.
df.shape
# Out:
# (5000, 3)

# %%
#Analizamos 10 resgistros del dataset
df.sample(10)
# Out:
#         id  label                                              tweet
# 4345  4346      0   @user air conditioning broke at the gym and t...
# 2236  2237      1  travelled for #canucks game sad and disappoint...
# 3159  3160      0  oh, and... and.... and... we have a hotel stay...
# 3364  3365      0  that man's daughter really must be of little v...
# 897    898      0  python27 and concurrency are not best friends,...
# 4524  4525      0  he'd rather kiss ð© than me! no boys will ev...
# 614    615      0  i am thankful for sweater weather. #thankful #...
# 994    995      1  who defines ?: historically #oppressed or hist...
# 419    420      0  euro 2016: bbc pundits make their predictions ...
# 4915  4916      0  now playing  :  michael nyman - " nyman: the p...

# %%
# Unicamente utilizaremos las columnas label y tweet. Descarto el campo id
df = df[['tweet','label']]

# %%
#Analizamos si hay valores nulos
df.isna().sum()
# Out:
# tweet    0
# label    0
# dtype: int64

# %%
# Analizamos la cantidad de tweets de cada etiqueta
print(df[df['label'] == 0].shape)
print(df[df['label'] == 1].shape)
# Out:
# (4659, 2)
# (341, 2)

# %% [markdown]
# # 3) Visualización
# Haremos uso del paquete wordcloud para generar una nube de palabras. (primeramente limpiaremos los datos)

# %%
df_1 = df[ df['label'] == 1]
df_1 = df_1['tweet']
df_0 = df[ df['label'] == 0]
df_0 = df_0['tweet']

# %%
# Ejemplo
df_0
# Out:
# 0        @user when a father is dysfunctional and is s...
# 1       @user @user thanks for #lyft credit i can't us...
# 2                                     bihday your majesty
# 3       #model   i love u take with u all the time in ...
# 4                  factsguide: society now    #motivation
#                               ...
# 4995    this wasn't only an attack on the lgbt communi...
# 4996     @user looking forward to catching you there? ...
# 4997    3 apps to help keep you   &amp; #healthy ðð...
# 4998    @user #bestsellers #top10 #sales    "never go ...
# 4999    any reaction to a volatile situation without t...
# Name: tweet, Length: 4659, dtype: object

# %%
#Generamos una nube de palabras y se eliminan palabras que inicien con simbolos que hacen referencia a hashtags , menciones o links y retweets.
def nube_de_palabras(data, color = 'white'):
    words = ' '.join(data)
    ''' 
    '''
    cleaned_word = " ".join([word for word in words.split()
                            if 'http' not in word
                                and not word.startswith('@')
                                and not word.startswith('#')
                                and word.lower() != 'rt'
                            ])
    wordcloud = WordCloud(stopwords=STOPWORDS,
                          collocations=False,
                      background_color=color,
                      width=2500,
                      height=2000
                     ).generate(cleaned_word)
    plt.figure(1,figsize=(12, 12))
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()
    
print("Palabras relacionadas con racismo/sexismo")
nube_de_palabras(df_1,'black')
print("Palabras no relacionadas con racismo/sexismo")
nube_de_palabras(df_0)
# Out:
# Palabras relacionadas con racismo/sexismo
# Palabras no relacionadas con racismo/sexismo

# %%
#Ejemplos:  
#df_1[156]

# %%
#df_0[64]

# %% [markdown]
# # 4) Limpieza dataset
# Sabiendo que son tweets podemos proponernos remover remover links, menciones, hashtags, stopwords del dataset (similar a lo realizado para la nube de palabras)

# %%
#Palabras a minúsculas
df['tweet'] = df['tweet'].apply(lambda x: x.lower())

# %%
#Elimina todos los caracteres no alfanuméricos
df['tweet'] = df['tweet'].apply((lambda x: re.sub('[^a-zA-z0-9\s]','',x)))

# %%
#Elimina referencias a retweets (identificados por 'rt', reemplazados por espacio)
for idx,row in df.iterrows():
    row[0] = row[0].replace('rt',' ')

# %%
#Stopwords
set(stopwords.words("english"))
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
# Armamos una funcion, la cual al pasarle un dataset, ejecuta varias acciones de limpieza
def acciones(dataset):
    tweets = []
    #Utilizamos una lista de stopwords de ingles
    stopwords_set = set(stopwords.words("english"))
    #Iteracion
    for index, row in dataset.iterrows():
        #Filtro para palabras muy cortas y transforma a minúscula
        words_filtered = [e.lower() for e in row.tweet.split() if len(e) >= 3]
        #Filtros generales
        words_cleaned = [word for word in words_filtered
            if 'http' not in word
            and not word.startswith('@')
            and not word.startswith('#') 
            and not word.startswith('ð')
            and not word.startswith('â')
            and word != 'RT']
        
        words_without_stopwords = [word for word in words_cleaned if not word in stopwords_set]
        #Se une todo en un mismo vector
        tweets.append((words_without_stopwords,row.label))
    return tweets

# %%
#Pasamos la funcion por el dataset
df=acciones(df)

# %% [markdown]
# Separaremos a continuación los datos en dos set de datos: train y test (función train_test_split), reservando un 15% de los datos  para testear los modelos.

# %%
tweets_train, tweets_test = train_test_split(df,test_size = 0.15)

# %%
#Miremos un ejemplo del resultado posterior a la limpieza
tweets_train[502]
# Out:
# (['already',
#   'good',
#   'sta',
#   'week',
#   'thanks',
#   'balanceldn',
#   'user',
#   'monday',
#   'balanceldn'],
#  0)

# %% [markdown]
# # **1do Modelo - Clasificador Bayesiano Ingenuo**

# %% [markdown]
# Uniremos todas las palabras en una única lista (aun si están repetidas) para luego contar la frecuencia de aparición de cada una

# %%
# Funcion para listar palabras
def listado(tweets):
    all = []
    for (tweet, label) in tweets:
        all.extend(tweet)
    return all

palabras_unidas = listado(tweets_train)

# %%
# Veamos el resultado
palabras_unidas
# Out:
# ['people',
#  'say',
#  'good',
#  'hea',
#  'always',
#  'think',
#  'good',
#  'hea',
#  'times',
#  'get',
#  'user',
#  'great',
#  'things',
#  'small',
#  'things',
#  'great',
#  'love',
#  'mother',
#  'teresa',
#  'love',
#  'women',
#  'first',
#  'presentation',
#  'user',
#  'netherlands',
#  'user',
#  'user',
#  'woah',
#  'yeah',
#  'finally',
#  'beginning',
#  'show',
#  'proud',
#  'user',
#  'yeahhhh',
#  'beautiful',
#  'bobo',
#  'love',
#  'friends',
#  'dinner',
#  'pretty',
#  'banner',
#  'merry',
#  'christmas',
#  'new',
#  'year',
#  'freepik',
#  'decoration',
#  'newyear',
#  'late',
#  'night',
#  'friday',
#  'featuring',
#  'latest',
#  'qsb',
#  'humor',
#  'comedy',
#  'business',
#  'smavisuals',
#  'user',
#  'user',
#  'user',
#  'user',
#  'dems',
#  'packing',
#  'house',
#  'crossing',
#  'vote',
#  'open',
#  'prim',
#  'done',
#  'flight',
#  'delayed',
#  'nearly',
#  '5hrs',
#  'ampfrustrated',
#  'mentally',
#  'maybe',
#  '16yrs',
#  'gameshow',
#  'bull',
#  'hill',
#  'climb',
#  'reach',
#  'target',
#  'complete',
#  'task',
#  'survive',
#  'strong',
#  'excit',
#  'see',
#  'happy',
#  'face',
#  'everything',
#  'smile',
#  'thegoodlife',
#  'camping',
#  'mainus',
#  'plak',
#  'sucks',
#  'want',
#  'comfo',
#  'person',
#  'give',
#  'insensitive',
#  'huing',
#  'aww',
#  'yeah',
#  'good',
#  'bing',
#  'bong',
#  'bing',
#  'bong',
#  'one',
#  'year',
#  'today',
#  'best',
#  'friend',
#  'world',
#  'years',
#  'marries',
#  'one',
#  'best',
#  'guys',
#  'around',
#  'cantwait',
#  'monday',
#  'nights',
#  '8pm',
#  'channel',
#  'finally',
#  'get',
#  'see',
#  'fuss',
#  'user',
#  'happy',
#  'dog',
#  'ditch',
#  'dog',
#  'dogsoftwitter',
#  'happiness',
#  'love',
#  'life',
#  'more_night_club',
#  'paytime',
#  'weekend',
#  'lifestyle',
#  'lalala',
#  'club',
#  'user',
#  'back',
#  'user',
#  'traumatic',
#  'months',
#  'damage',
#  'bad',
#  'thought',
#  'proof',
#  'plan',
#  'works',
#  'onwards',
#  'amp',
#  'upwards',
#  'excit',
#  'hey',
#  'saw',
#  'youre',
#  'fitness',
#  'fan',
#  'invite',
#  'test',
#  'free',
#  'app',
#  'called',
#  'training',
#  'appstore',
#  'user',
#  'user',
#  'followi',
#  'hope',
#  'well',
#  'world',
#  'postpone',
#  'mirror',
#  'witch',
#  'next',
#  'week',
#  'shinhyes',
#  'drama',
#  'list',
#  'amp',
#  'amp',
#  'amp',
#  'uncontrollably',
#  'fond',
#  'creating',
#  'right',
#  'beats',
#  'makingbeats',
#  'thursday',
#  'work',
#  'istandard',
#  'akaipro',
#  'user',
#  'america',
#  'needs',
#  'tough',
#  'legislation',
#  'guncontrolplease',
#  'paying',
#  'lip',
#  'service',
#  'gunviolence',
#  'loveconquersha',
#  'user',
#  'user',
#  'brilliantly',
#  'adveising',
#  'percypigs',
#  'marshall',
#  'omg',
#  'new',
#  'orange',
#  'new',
#  'black',
#  'season',
#  'netflix',
#  'soon',
#  'cant',
#  'wait',
#  'looking',
#  'back',
#  'people',
#  'middle',
#  'school',
#  'linkinbio',
#  'polar',
#  'bear',
#  'climb',
#  'racing',
#  'angry',
#  'polar',
#  'bear',
#  'climb',
#  'racing',
#  'polar',
#  'bear',
#  'living',
#  'cold',
#  'places',
#  'lips',
#  'like',
#  'fire',
#  'blood',
#  'like',
#  'gasoline',
#  'love',
#  'boyfriend',
#  'smile',
#  'sunday',
#  'vibes',
#  'sunday',
#  'vibes',
#  'game',
#  'holiday',
#  'enjoy',
#  'theres',
#  'always',
#  'reason',
#  'smile',
#  'love',
#  'lovely',
#  'cute',
#  'xoxo',
#  'happy',
#  'things',
#  'place',
#  'scuba',
#  'stuff',
#  'beginning',
#  'user',
#  'gave',
#  'away',
#  'wings',
#  'sad',
#  'see',
#  'fly',
#  'antonio',
#  'porchia',
#  'oxford',
#  'boat',
#  'trip',
#  'oxford',
#  'travelerslife',
#  'love',
#  'igers',
#  'latino',
#  'spanish',
#  'funday',
#  'sunny',
#  'broken',
#  'heas',
#  'nomakeup',
#  'justeyelashes',
#  'beberexaftnickiminaj',
#  'ponytail',
#  'kiss',
#  'smile',
#  'lov',
#  'herofathersday',
#  'dad',
#  'daddy',
#  'luckysuperdad',
#  'heroamazing',
#  'caoon',
#  'transition',
#  'pack',
#  'animation',
#  'anime',
#  'children',
#  'colorful',
#  'cute',
#  'funny',
#  'kids',
#  'whatever',
#  'give',
#  'god',
#  'trust',
#  'straighten',
#  'fathers',
#  'day',
#  'amazing',
#  'dad',
#  'euro16',
#  'begin',
#  'wow',
#  'fozza',
#  'italia',
#  'user',
#  'biggest',
#  'lebron',
#  'hater',
#  'eah',
#  'profitable',
#  'thing',
#  'america',
#  'know',
#  'essential',
#  'oils',
#  'made',
#  'chemicals',
#  'youre',
#  'mother',
#  'stands',
#  'pretheatre',
#  'lunch',
#  'date',
#  'justroses',
#  'make',
#  'loved',
#  'one',
#  'loved',
#  'instalove',
#  'instacool',
#  'send',
#  'redrose',
#  'thanx',
#  'user',
#  'love',
#  'couple',
#  'cute',
#  'adorable',
#  'hugs',
#  'romance',
#  'forever',
#  'girlfriend',
#  'smile',
#  'beautiful',
#  'twitter',
#  'mentions',
#  'tavern',
#  'phipps',
#  'user',
#  'happy',
#  'friday',
#  'lunchtime',
#  'atlanta',
#  'phippsplaza',
#  'friendszxc',
#  'shockingly',
#  'increasingly',
#  'violent',
#  'world',
#  'live',
#  'gun',
#  'control',
#  'laws',
#  'feel',
#  'mps',
#  'family',
#  'amp',
#  'friends',
#  'user',
#  'happy',
#  'wednesday',
#  'hope',
#  'day',
#  'amazing',
#  'wednesday',
#  'namaste',
#  'saintjohn',
#  'dreamcatcher',
#  'bull',
#  'dominate',
#  'bull',
#  'direct',
#  'whatever',
#  'want',
#  'couldnt',
#  'sleep',
#  'night',
#  'bridal',
#  'shower',
#  'world',
#  'going',
#  'sleep',
#  'day',
#  'wedding',
#  'might',
#  'libtard',
#  'libtard',
#  'sjw',
#  'liberal',
#  'politics',
#  'tomorrow',
#  'day',
#  'babykroixontheway',
#  '33weeks',
#  'weslayin',
#  'yes',
#  'saying',
#  'hillaryclintons',
#  'major',
#  'qualification',
#  'female',
#  'sorry',
#  'folks',
#  'deal',
#  'find',
#  'nothing',
#  'else',
#  'really',
#  'lovely',
#  'bihday',
#  'spoilt',
#  'family',
#  'love',
#  'bihday',
#  'user',
#  'user',
#  'user',
#  'truly',
#  'truly',
#  'pathetic',
#  'many',
#  'ways',
#  'user',
#  'user',
#  'user',
#  'nothing',
#  'learned',
#  'coverin',
#  'riskaversion',
#  'grips',
#  'europe',
#  'dax',
#  'drops',
#  'blog',
#  'silver',
#  'gold',
#  'forex',
#  'user',
#  'drop',
#  'feelings',
#  'hostility',
#  'ill',
#  'amp',
#  'wherever',
#  'choose',
#  'goatisa',
#  'iampeace',
#  'user',
#  'harry',
#  'potter',
#  'tickets',
#  'arrived',
#  'user',
#  'harrypotter',
#  'winter',
#  'menu',
#  'coming',
#  'soon',
#  'thegrove',
#  'newmenu',
#  'pies',
#  'lambshanks',
#  'pasta',
#  'work',
#  'today',
#  'please',
#  'answer',
#  'quick',
#  'survey',
#  'leadership',
#  'quick',
#  'read',
#  'training',
#  'selfdevelopmenttime',
#  'betteryourself',
#  'beanythingyouwanttobe',
#  'healthy',
#  'friday',
#  'get',
#  'excited',
#  'treat',
#  'one',
#  'delicious',
#  'bagel',
#  'sandwiches',
#  'talented',
#  'young',
#  'lady',
#  'model',
#  'love',
#  'take',
#  'time',
#  'many',
#  'great',
#  'things',
#  'happening',
#  'godisgreat',
#  'thankful',
#  'thankful',
#  'positive',
#  'user',
#  'user',
#  'user',
#  'going',
#  'script',
#  'right',
#  'women',
#  'nude',
#  'anal',
#  'anal',
#  'girls',
#  'nice',
#  'way',
#  'sta',
#  'bihday',
#  'work',
#  'bihday',
#  'work',
#  'brisbane',
#  'break',
#  'bad',
#  'habit',
#  'success',
#  'courage',
#  'education',
#  'choices',
#  'cope',
#  'aww',
#  'yeah',
#  'good',
#  'bing',
#  'bong',
#  'bing',
#  'bong',
#  'user',
#  'deserves',
#  'said',
#  'user',
#  'well',
#  'truly',
#  'spoilt',
#  'today',
#  'cant',
#  'wait',
#  'try',
#  'peanutbutteralcohol',
#  'bihdaydrinks',
#  'fruit',
#  'happy',
#  'bihday',
#  'chris',
#  'evans',
#  'great',
#  'actor',
#  'human',
#  'chrisevans',
#  'bihday',
#  'tried',
#  'new',
#  'user',
#  'trailn2v3',
#  'today',
#  'although',
#  'feel',
#  'similar',
#  'v2s',
#  'v3s',
#  'smoother',
#  'feel',
#  'great',
#  'taking',
#  'sister',
#  'first',
#  'ever',
#  'conce',
#  'big',
#  'one',
#  'user',
#  'coldplaywembley',
#  'ill',
#  'never',
#  'understand',
#  'folks',
#  'waste',
#  'away',
#  'health',
#  'amp',
#  'life',
#  'using',
#  'drugs',
#  'cherry',
#  'blossoms',
#  'strawberries',
#  'benguet',
#  'aint',
#  'good',
#  'tourists',
#  'happy',
#  'hours',
#  'flip',
#  'leather',
#  'hybrid',
#  'wallet',
#  'hours',
#  'flip',
#  'leather',
#  'finally',
#  'got',
#  'furniture',
#  'paid',
#  'babe',
#  'ampamp',
#  'paid',
#  'months',
#  'advance',
#  'finally',
#  'mine',
#  'user',
#  'user',
#  'simon',
#  'homophobic',
#  'assholes',
#  'dont',
#  'need',
#  'find',
#  'excuse',
#  'mind',
#  'everything',
#  'caused',
#  'equal',
#  'rights',
#  'senate',
#  'gop',
#  'drops',
#  'push',
#  'defund',
#  'obamacare',
#  'work',
#  'freestylehairhairstylehairdresser',
#  'thankyougoodcool',
#  'user',
#  'time',
#  'everyone',
#  'becomes',
#  'nudist',
#  'nudist',
#  'nudism',
#  'freedom',
#  'lifestyle',
#  'sweat',
#  'thanks',
#  'babygirl',
#  'hmu',
#  'gay',
#  'xoxo',
#  'people',
#  'away',
#  'reaching',
#  '100',
#  'followers',
#  'twitch',
#  'stream',
#  'streamer',
#  'gamer',
#  'almostthere',
#  'sharethelove',
#  'ian',
#  'darke',
#  'never',
#  'misses',
#  'chance',
#  'slag',
#  'homeland',
#  'gtgt',
#  'wow',
#  'i_am',
#  'positive',
#  'affirmation',
#  'beginning',
#  'think',
#  'user',
#  'tom',
#  'brady',
#  'hater',
#  'way',
#  'goes',
#  'man',
#  'user',
#  'guys',
#  'gonna',
#  'tlc',
#  'anymore',
#  'newfielove',
#  'like',
#  'pizza',
#  'cone',
#  'tahini',
#  'spinach',
#  'crackers',
#  'user',
#  'cnn',
#  'calls',
#  'michigan',
#  'middle',
#  'school',
#  'build',
#  'wall',
#  'chant',
#  'tcot',
#  'teen',
#  'girl',
#  'killed',
#  'others',
#  'injured',
#  'downtown',
#  'oakland',
#  'shooting',
#  'guns',
#  'mentalillness',
#  'gangs',
#  'orlando',
#  'never',
#  'appropriate',
#  'zero',
#  'idea',
#  'feeling',
#  'right',
#  'scared',
#  'missyou',
#  'whatwasthat',
#  'bring',
#  'sunshine',
#  'zen',
#  'everydaybeautiful',
#  'mindfulness',
#  'sun',
#  'witness',
#  'divisive',
#  'theunitedstates',
#  'become',
#  'democrats',
#  'insult',
#  'republicans',
#  'amp',
#  'viceversa',
#  'arent',
#  'americans',
#  'potus',
#  'white',
#  'hed',
#  'still',
#  'worst',
#  'president',
#  'ever',
#  'likely',
#  'president',
#  'ever',
#  'trump',
#  'israel',
#  'happynewyear',
#  'thanks',
#  'bitch',
#  'sparkles',
#  'loves',
#  'appreciates',
#  'trust',
#  'findom',
#  'cashgoddess',
#  'goodluck',
#  'goodfoune',
#  'selfish',
#  'orlando',
#  'standwithorlando',
#  'pulseshooting',
#  'orlandoshooting',
#  'biggerproblems',
#  'selfish',
#  'heabreaking',
#  'values',
#  'love',
#  'fathers',
#  'day',
#  'take',
#  'dad',
#  'user',
#  'love',
#  'user',
#  'ummhmm',
#  'fair',
#  'way',
#  'nightshift',
#  'stanley',
#  'cup',
#  'conn',
#  'smythe',
#  'trophy',
#  'building',
#  'sharks',
#  'oksrslywhen',
#  'people',
#  'dont',
#  'know',
#  'theyre',
#  'talking',
#  'shouldnt',
#  'talking',
#  'great',
#  'day',
#  'parents',
#  'sasquatchbrewing',
#  'mexicanfood',
#  'japanesegardens',
#  'polandhills',
#  'find',
#  'user',
#  'really',
#  'inspiring',
#  'unlike',
#  'user',
#  'gone',
#  'nice',
#  'inspiring',
#  'really',
#  'obnoxious',
#  'full',
#  'kids',
#  'polar',
#  'bear',
#  'climb',
#  'racing',
#  'angry',
#  'polar',
#  'bear',
#  'climb',
#  'racing',
#  'polar',
#  'bear',
#  'living',
#  'cold',
#  'places',
#  'looking',
#  'difficult',
#  'roads',
#  'often',
#  'lead',
#  'beautiful',
#  'destinations',
#  'anon',
#  'leadership',
#  'inspiration',
#  'quote',
#  'inspirational',
#  'thriving',
#  'i_am',
#  'positive',
#  'affirmation',
#  'user',
#  'services',
#  'betterbefixedsoon',
#  'sad',
#  'pet',
#  'dog',
#  'lol',
#  'ptrish_g32',
#  'love',
#  'sun',
#  'sunnyday',
#  'hot',
#  'holiday',
#  'sandossanblas',
#  'girl',
#  'gpodtimes',
#  'nochebuena',
#  'lasvegas',
#  'usa',
#  'las',
#  'vegas',
#  'strip',
#  'user',
#  'parking',
#  'one',
#  'member',
#  'staff',
#  'okay',
#  'way',
#  'car',
#  'wasnt',
#  'hit',
#  'happy',
#  'morning',
#  '8degree',
#  'anna',
#  'classmate',
#  'friends',
#  'user',
#  'user',
#  'user',
#  'hehe',
#  'looks',
#  'like',
#  'found',
#  'approximate',
#  'date',
#  'somuchfunlasttime',
#  'user',
#  'yes',
#  'lets',
#  'thissuppoing',
#  'openly',
#  'prowar',
#  'anti',
#  'islamichomophobicrapistwho',
#  'advocates',
#  'samehypocrite',
#  'gameshow',
#  'bull',
#  'hill',
#  'climb',
#  'reach',
#  'target',
#  'complete',
#  'task',
#  'survive',
#  'strong',
#  'excit',
#  'fathersdaymessage',
#  'fathers',
#  'day',
#  'message',
#  'buy',
#  'things',
#  'happy',
#  'fathers',
#  'day',
#  'funny',
#  'air',
#  'dome',
#  'seibu',
#  'stadium',
#  'children',
#  'play',
#  'follow',
#  'instagood',
#  'trip',
#  'travel',
#  'user',
#  'user',
#  'yay',
#  'fantastic',
#  'edinburgh',
#  'user',
#  'reading',
#  'make',
#  'happier',
#  'via',
#  'user',
#  ...]

# %% [markdown]
# A partir de la lista palabras_unidas podemos calcular la frecuencia de aparición de cada una de las palabras usando la función nltk.FreqDist .

# %%
def frecuencia_de_palabras(lista_completa):
    palabras_freq = nltk.FreqDist(lista_completa)
    return palabras_freq

frecuencia = frecuencia_de_palabras(palabras_unidas)

# %%
# Listamos cantidad de apariciones de cada palabra ordenadas
frecuencia = sorted(frecuencia.items(), key=lambda x:x[1], reverse=True)
frecuencia = dict(frecuencia)
frecuencia
# Out:
# {'user': 2193,
#  'love': 369,
#  'day': 320,
#  'happy': 262,
#  'amp': 223,
#  'life': 147,
#  'today': 142,
#  'time': 141,
#  'like': 135,
#  'bihday': 135,
#  'positive': 126,
#  'new': 125,
#  'thankful': 125,
#  'people': 119,
#  'one': 114,
#  'good': 113,
#  'get': 113,
#  'fathers': 105,
#  'see': 103,
#  'dont': 103,
#  'cant': 91,
#  'smile': 88,
#  'take': 85,
#  'way': 84,
#  'weekend': 82,
#  'fun': 80,
#  'work': 79,
#  'want': 77,
#  'healthy': 76,
#  'summer': 75,
#  'bull': 71,
#  'family': 69,
#  'friends': 68,
#  'friday': 68,
#  'best': 68,
#  'got': 68,
#  'happiness': 66,
#  'days': 66,
#  'back': 65,
#  'make': 65,
#  'first': 64,
#  'beautiful': 63,
#  'going': 62,
#  'blog': 62,
#  'really': 61,
#  'music': 61,
#  'ready': 61,
#  'tomorrow': 59,
#  'world': 58,
#  'week': 58,
#  'sad': 58,
#  'need': 58,
#  'wait': 57,
#  'fathersday': 57,
#  'great': 55,
#  'always': 53,
#  'affirmation': 53,
#  'orlando': 53,
#  'think': 52,
#  'right': 52,
#  'silver': 52,
#  'model': 52,
#  'morning': 51,
#  'sunday': 50,
#  'gold': 50,
#  'never': 50,
#  'much': 50,
#  'know': 48,
#  'home': 48,
#  'finally': 47,
#  'dad': 47,
#  'feel': 46,
#  'find': 46,
#  'girl': 46,
#  'next': 45,
#  'cute': 45,
#  'forex': 45,
#  'well': 44,
#  'i_am': 44,
#  'say': 43,
#  'things': 43,
#  'youre': 43,
#  'trump': 43,
#  'show': 42,
#  'night': 42,
#  'live': 42,
#  'girls': 42,
#  'last': 42,
#  'little': 42,
#  'makes': 42,
#  'year': 41,
#  'amazing': 41,
#  'another': 41,
#  'hope': 40,
#  'blessed': 40,
#  'getting': 39,
#  'even': 39,
#  'feeling': 38,
#  'old': 38,
#  'thank': 38,
#  'looking': 37,
#  'many': 37,
#  'man': 37,
#  'sun': 36,
#  'still': 36,
#  'via': 36,
#  'altwaystoheal': 36,
#  'enjoy': 35,
#  'sta': 35,
#  'tonight': 35,
#  'game': 34,
#  'ever': 34,
#  'come': 34,
#  'hate': 34,
#  'buffalo': 34,
#  'would': 34,
#  'may': 34,
#  'yes': 33,
#  'follow': 33,
#  'look': 33,
#  '2016': 33,
#  'better': 33,
#  'climb': 32,
#  'bear': 32,
#  'made': 32,
#  'thanks': 32,
#  'years': 31,
#  'dog': 31,
#  'might': 31,
#  'selfie': 31,
#  'pay': 31,
#  'friend': 30,
#  'free': 30,
#  'soon': 30,
#  'whatever': 30,
#  'quote': 30,
#  'cool': 30,
#  'peace': 30,
#  'awesome': 30,
#  'hea': 29,
#  'school': 29,
#  'nothing': 29,
#  'everyone': 29,
#  'video': 29,
#  'lost': 29,
#  'watch': 29,
#  'father': 29,
#  'stop': 28,
#  'saturday': 28,
#  'end': 28,
#  'motivation': 28,
#  'guys': 27,
#  'around': 27,
#  'polar': 27,
#  'coming': 27,
#  'excited': 27,
#  'every': 27,
#  'believe': 27,
#  'two': 27,
#  'ive': 27,
#  'food': 27,
#  'without': 27,
#  'strong': 26,
#  'monday': 26,
#  'white': 26,
#  'city': 26,
#  'baby': 26,
#  'thats': 26,
#  'beach': 26,
#  'proud': 25,
#  'house': 25,
#  'bad': 25,
#  'away': 25,
#  'children': 25,
#  'god': 25,
#  'found': 25,
#  'playing': 25,
#  'didnt': 25,
#  'dads': 25,
#  'kids': 24,
#  'dominate': 24,
#  'direct': 24,
#  'wedding': 24,
#  'lol': 24,
#  'travel': 24,
#  'let': 24,
#  'healing': 24,
#  'news': 24,
#  'black': 23,
#  'angry': 23,
#  'holiday': 23,
#  'funny': 23,
#  'nice': 23,
#  'long': 23,
#  'weeks': 23,
#  'keep': 23,
#  'lt3': 23,
#  'something': 23,
#  'thing': 22,
#  'young': 22,
#  'big': 22,
#  'gonna': 22,
#  'play': 22,
#  'instagood': 22,
#  'power': 22,
#  'fashion': 22,
#  'sex': 22,
#  'doesnt': 22,
#  'yeah': 21,
#  'hot': 21,
#  'looks': 21,
#  'attack': 21,
#  'help': 21,
#  'check': 21,
#  'boy': 21,
#  'dance': 21,
#  'waiting': 21,
#  'money': 21,
#  'women': 20,
#  'everything': 20,
#  'give': 20,
#  'daddy': 20,
#  'twitter': 20,
#  'inspiration': 20,
#  'song': 20,
#  'left': 20,
#  'making': 20,
#  'true': 20,
#  'grateful': 20,
#  'quotes': 20,
#  'joy': 20,
#  'porn': 20,
#  'rip': 20,
#  'wonderful': 20,
#  'someone': 20,
#  'mindset': 20,
#  'watching': 20,
#  'wish': 20,
#  'dogs': 20,
#  'done': 19,
#  'america': 19,
#  'season': 19,
#  'place': 19,
#  'libtard': 19,
#  'health': 19,
#  'forward': 19,
#  'leave': 19,
#  'sexy': 19,
#  'hour': 19,
#  'use': 19,
#  'fans': 19,
#  'moment': 19,
#  'team': 19,
#  'person': 18,
#  'racing': 18,
#  'living': 18,
#  'please': 18,
#  'till': 18,
#  'anyone': 18,
#  'simulation': 18,
#  'says': 18,
#  'isnt': 18,
#  'daily': 18,
#  'snapchat': 18,
#  'talk': 18,
#  'wont': 18,
#  'miss': 18,
#  'future': 18,
#  'crazy': 18,
#  'face': 17,
#  'fan': 17,
#  'lovely': 17,
#  'date': 17,
#  'loved': 17,
#  'ill': 17,
#  'gay': 17,
#  'goes': 17,
#  'lets': 17,
#  'head': 17,
#  'followme': 17,
#  'hair': 17,
#  'photo': 17,
#  'guy': 17,
#  'racist': 17,
#  'woman': 17,
#  'job': 17,
#  'tweets': 17,
#  'truth': 17,
#  'business': 16,
#  'bing': 16,
#  'bong': 16,
#  'couple': 16,
#  'forever': 16,
#  'success': 16,
#  'usa': 16,
#  'yay': 16,
#  'london': 16,
#  'daughter': 16,
#  'tbt': 16,
#  'put': 16,
#  'gets': 16,
#  'real': 16,
#  'conference': 16,
#  'shop': 16,
#  'mom': 16,
#  'month': 16,
#  'already': 16,
#  'story': 16,
#  'change': 16,
#  'june': 16,
#  'stay': 16,
#  'could': 16,
#  'book': 16,
#  'vote': 15,
#  'training': 15,
#  'omg': 15,
#  'cold': 15,
#  'trip': 15,
#  'politics': 15,
#  'education': 15,
#  'try': 15,
#  'mind': 15,
#  'freedom': 15,
#  'become': 15,
#  'talking': 15,
#  'full': 15,
#  'men': 15,
#  'remember': 15,
#  'son': 15,
#  'also': 15,
#  'loving': 15,
#  'obama': 15,
#  'shit': 15,
#  'mood': 15,
#  'tell': 15,
#  'meet': 15,
#  'color': 15,
#  'kid': 15,
#  'sweet': 15,
#  'alone': 15,
#  'hello': 15,
#  'favorite': 15,
#  'delete': 15,
#  'useful': 15,
#  'deletetweets': 15,
#  'football': 15,
#  'relax': 15,
#  'lot': 15,
#  'seeing': 15,
#  'open': 14,
#  'gun': 14,
#  'control': 14,
#  'else': 14,
#  'hours': 14,
#  'gone': 14,
#  'car': 14,
#  'hit': 14,
#  'vacation': 14,
#  'actually': 14,
#  'care': 14,
#  'race': 14,
#  'film': 14,
#  'homes': 14,
#  'high': 14,
#  'nyc': 14,
#  'yet': 14,
#  'half': 14,
#  'euro2016': 14,
#  'since': 14,
#  'win': 14,
#  'hes': 14,
#  'hear': 14,
#  'close': 14,
#  'poetry': 14,
#  'came': 14,
#  'call': 14,
#  'depression': 14,
#  'pretty': 13,
#  'complete': 13,
#  'fitness': 13,
#  'needs': 13,
#  'wow': 13,
#  'liberal': 13,
#  'sorry': 13,
#  'said': 13,
#  'anymore': 13,
#  'others': 13,
#  'buy': 13,
#  'empty': 13,
#  'kill': 13,
#  'word': 13,
#  'photooftheday': 13,
#  'almost': 13,
#  'cat': 13,
#  'vicinity': 13,
#  'dream': 13,
#  'sick': 13,
#  'guess': 13,
#  'hard': 13,
#  'suppoers': 13,
#  'share': 13,
#  'join': 13,
#  'flowers': 13,
#  'heal': 13,
#  'body': 13,
#  'poor': 13,
#  'rest': 13,
#  'bday': 13,
#  'tired': 13,
#  'red': 13,
#  'comes': 13,
#  'bed': 13,
#  'perfect': 13,
#  'enough': 13,
#  'dinner': 12,
#  'target': 12,
#  'months': 12,
#  'thought': 12,
#  'app': 12,
#  'places': 12,
#  'gave': 12,
#  'sunny': 12,
#  'sleep': 12,
#  'arrived': 12,
#  'read': 12,
#  'bring': 12,
#  'oitnb': 12,
#  'environment': 12,
#  'lucky': 12,
#  'beer': 12,
#  'child': 12,
#  'violence': 12,
#  'hatred': 12,
#  'shes': 12,
#  'community': 12,
#  'safe': 12,
#  'country': 12,
#  'episode': 12,
#  'goodmorning': 12,
#  'retweet': 12,
#  'single': 12,
#  'gorilla': 12,
#  'whats': 12,
#  'booked': 12,
#  'learn': 12,
#  'leads': 12,
#  'dancing': 12,
#  'early': 12,
#  'top': 12,
#  'feels': 12,
#  'working': 12,
#  'listen': 12,
#  'media': 12,
#  'moments': 12,
#  'used': 12,
#  'coffee': 12,
#  'gift': 12,
#  'police': 12,
#  'latest': 11,
#  'survive': 11,
#  'lifestyle': 11,
#  'saw': 11,
#  'theres': 11,
#  'broken': 11,
#  'anime': 11,
#  'saying': 11,
#  'nude': 11,
#  'killed': 11,
#  'shooting': 11,
#  'arent': 11,
#  'americans': 11,
#  'went': 11,
#  'garden': 11,
#  'mean': 11,
#  'ramadan': 11,
#  'hands': 11,
#  'wrong': 11,
#  'drinks': 11,
#  'name': 11,
#  'park': 11,
#  'tear': 11,
#  'order': 11,
#  'smiling': 11,
#  'sure': 11,
#  'organizations': 11,
#  'faith': 11,
#  'families': 11,
#  'stas': 11,
#  'bride': 11,
#  'vine': 11,
#  'together': 11,
#  'social': 11,
#  'wants': 11,
#  'fact': 11,
#  'yoga': 11,
#  'rain': 11,
#  'words': 11,
#  'ripchristina': 11,
#  'videos': 11,
#  'brexit': 11,
#  'kind': 11,
#  'missing': 11,
#  'far': 11,
#  'hill': 10,
#  'reach': 10,
#  'task': 10,
#  'aww': 10,
#  'reason': 10,
#  'wednesday': 10,
#  'sjw': 10,
#  'truly': 10,
#  '100': 10,
#  'scared': 10,
#  'sunshine': 10,
#  'reading': 10,
#  'suppo': 10,
#  'meeting': 10,
#  'respect': 10,
#  'ppl': 10,
#  'post': 10,
#  'nervous': 10,
#  'anniversary': 10,
#  'fucking': 10,
#  'afternoon': 10,
#  'comments': 10,
#  'todays': 10,
#  'festival': 10,
#  'anything': 10,
#  'wishing': 10,
#  'beauty': 10,
#  'thoughts': 10,
#  'room': 10,
#  'simulator': 10,
#  'adapt': 10,
#  'dear': 10,
#  'sea': 10,
#  'india': 10,
#  'cultureofdevelopment': 10,
#  'bless': 10,
#  'growth': 10,
#  'bit': 10,
#  'staing': 10,
#  'woohoo': 10,
#  'calling': 10,
#  'england': 10,
#  'prayfororlando': 10,
#  'voice': 10,
#  'fuck': 10,
#  'muslim': 10,
#  'disney': 10,
#  'eat': 10,
#  'needed': 10,
#  'officially': 10,
#  'times': 9,
#  'mother': 9,
#  'cantwait': 9,
#  'club': 9,
#  'hey': 9,
#  'service': 9,
#  'vibes': 9,
#  'begin': 9,
#  'couldnt': 9,
#  'female': 9,
#  'feelings': 9,
#  'lady': 9,
#  'understand': 9,
#  'using': 9,
#  'teen': 9,
#  'wasnt': 9,
#  'glad': 9,
#  'though': 9,
#  'apple': 9,
#  'minute': 9,
#  'event': 9,
#  'celebrate': 9,
#  'birds': 9,
#  'lawofattraction': 9,
#  'huge': 9,
#  'lonely': 9,
#  'picture': 9,
#  'political': 9,
#  'seems': 9,
#  'less': 9,
#  'shoes': 9,
#  'puppy': 9,
#  'happen': 9,
#  'tupac': 9,
#  'cannot': 9,
#  'lose': 9,
#  'simple': 9,
#  'age': 9,
#  'number': 9,
#  'state': 9,
#  'allahsoil': 9,
#  'movie': 9,
#  'christina': 9,
#  'second': 9,
#  'mad': 9,
#  'woh': 9,
#  'question': 9,
#  'friendship': 9,
#  'leaving': 9,
#  'problem': 9,
#  'like4like': 9,
#  '1st': 9,
#  'florida': 9,
#  'ask': 9,
#  'cards': 9,
#  'altright': 9,
#  'tragedy': 9,
#  'view': 9,
#  'welcome': 9,
#  'super': 9,
#  'depressed': 9,
#  'ending': 9,
#  'damn': 9,
#  'weather': 9,
#  'gym': 9,
#  'brother': 9,
#  'forget': 9,
#  'whole': 9,
#  'hardcore': 9,
#  'yall': 9,
#  'missed': 9,
#  'beginning': 8,
#  'flight': 8,
#  'maybe': 8,
#  'thursday': 8,
#  'fire': 8,
#  'stuff': 8,
#  'folks': 8,
#  'pathetic': 8,
#  'ways': 8,
#  'choose': 8,
#  'tickets': 8,
#  'sister': 8,
#  'guns': 8,
#  'idea': 8,
#  'orlandoshooting': 8,
#  'parents': 8,
#  'inspirational': 8,
#  'side': 8,
#  'tears': 8,
#  'minutes': 8,
#  'nature': 8,
#  'memories': 8,
#  'singing': 8,
#  'wine': 8,
#  'instamood': 8,
#  'chicago': 8,
#  'style': 8,
#  'design': 8,
#  'creative': 8,
#  'price': 8,
#  'instagram': 8,
#  'death': 8,
#  'holidays': 8,
#  'animals': 8,
#  'tgif': 8,
#  'south': 8,
#  'dead': 8,
#  'weve': 8,
#  'tweet': 8,
#  'ago': 8,
#  'speak': 8,
#  'agree': 8,
#  'blue': 8,
#  'science': 8,
#  'instalike': 8,
#  'jobs': 8,
#  'lifeisgood': 8,
#  'cause': 8,
#  'water': 8,
#  'behind': 8,
#  'course': 8,
#  'shows': 8,
#  'save': 8,
#  'wtf': 8,
#  'ordered': 8,
#  'july': 8,
#  'wanna': 8,
#  'thinking': 8,
#  'lives': 8,
#  'google': 8,
#  'means': 8,
#  'everyday': 8,
#  'games': 8,
#  'able': 8,
#  'countdown': 8,
#  'probably': 8,
#  'mountains': 8,
#  'positivevibes': 8,
#  'smh': 8,
#  'train': 8,
#  'niggas': 8,
#  'ireland': 8,
#  'rather': 8,
#  'lgbt': 8,
#  'makeup': 8,
#  'youve': 8,
#  'victims': 8,
#  'picoftheday': 8,
#  'laugh': 8,
#  'gbp': 8,
#  'cats': 8,
#  'matter': 8,
#  'blur': 8,
#  'alive': 8,
#  'toptags': 8,
#  'sign': 8,
#  'small': 7,
#  'nights': 7,
#  'test': 7,
#  'list': 7,
#  'middle': 7,
#  'boyfriend': 7,
#  'xoxo': 7,
#  'fly': 7,
#  'kiss': 7,
#  'europe': 7,
#  'leadership': 7,
#  'treat': 7,
#  'happening': 7,
#  'break': 7,
#  'actor': 7,
#  'taking': 7,
#  'conce': 7,
#  'mine': 7,
#  'followers': 7,
#  'gamer': 7,
#  'president': 7,
#  'bitch': 7,
#  'died': 7,
#  'run': 7,
#  'htt': 7,
#  'society': 7,
#  'offer': 7,
#  'bought': 7,
#  'begins': 7,
#  'past': 7,
#  'behappy': 7,
#  'affirmations': 7,
#  'reasons': 7,
#  'bout': 7,
#  'husband': 7,
#  'xxx': 7,
#  'nasty': 7,
#  'shy': 7,
#  'california': 7,
#  'remain': 7,
#  'pink': 7,
#  'index': 7,
#  'successful': 7,
#  'must': 7,
#  'congrats': 7,
#  'system': 7,
#  'ahead': 7,
#  'shopping': 7,
#  'prayers': 7,
#  'smiles': 7,
#  'sold': 7,
#  'office': 7,
#  'light': 7,
#  'ones': 7,
#  'gaming': 7,
#  'yesterday': 7,
#  'loveit': 7,
#  'celebration': 7,
#  'nofilter': 7,
#  'adventure': 7,
#  'pray': 7,
#  'cry': 7,
#  'instead': 7,
#  'cake': 7,
#  'beyond': 7,
#  'pop': 7,
#  'japan': 7,
#  'wouldnt': 7,
#  'bus': 7,
#  'driver': 7,
#  'ibiza': 7,
#  'piano': 7,
#  'count': 7,
#  'pulse': 7,
#  'goal': 7,
#  'line': 7,
#  'taken': 7,
#  'spend': 7,
#  'review': 7,
#  'positivity': 7,
#  'running': 7,
#  'vegan': 7,
#  'cleveland': 7,
#  'cavs': 7,
#  'exciting': 7,
#  'naked': 7,
#  'tuesday': 7,
#  'energy': 7,
#  'schools': 7,
#  'politicians': 7,
#  'impoant': 7,
#  'fine': 7,
#  'company': 7,
#  'tech': 7,
#  'racism': 7,
#  'point': 7,
#  'area': 7,
#  'chocolate': 7,
#  'fear': 7,
#  'enjoying': 7,
#  'heading': 7,
#  'binge': 7,
#  'secret': 7,
#  'staed': 7,
#  'fast': 7,
#  'fight': 7,
#  'special': 7,
#  'wanted': 7,
#  'drink': 7,
#  'asian': 7,
#  'fresh': 7,
#  'seen': 7,
#  'present': 7,
#  'shot': 7,
#  'boys': 7,
#  'thankyou': 7,
#  'instadaily': 7,
#  'series': 7,
#  'hotel': 7,
#  'flag': 7,
#  'e32016': 7,
#  'die': 7,
#  'rock': 7,
#  'pic': 7,
#  'anxiety': 7,
#  'absolutely': 7,
#  'bigotry': 7,
#  'ness': 7,
#  'happened': 7,
#  'pain': 7,
#  'babies': 7,
#  'comedy': 6,
#  'works': 6,
#  'pack': 6,
#  'trust': 6,
#  'biggest': 6,
#  'lunch': 6,
#  'delicious': 6,
#  'human': 6,
#  'aint': 6,
#  'gop': 6,
#  'pizza': 6,
#  'loves': 6,
#  'difficult': 6,
#  'staff': 6,
#  'yolo': 6,
#  'emotions': 6,
#  'market': 6,
#  'poland': 6,
#  'finish': 6,
#  'donald': 6,
#  'fucked': 6,
#  'scotland': 6,
#  'supposed': 6,
#  'imagine': 6,
#  'experience': 6,
#  'stand': 6,
#  'youtube': 6,
#  'neverump': 6,
#  'candidate': 6,
#  'luck': 6,
#  'move': 6,
#  'feet': 6,
#  'passion': 6,
#  'hump': 6,
#  'wear': 6,
#  'islam': 6,
#  'ladies': 6,
#  'wet': 6,
#  'least': 6,
#  'udtapunjab': 6,
#  'worry': 6,
#  'interesting': 6,
#  'bright': 6,
#  'island': 6,
#  'tragic': 6,
#  'clients': 6,
#  'source': 6,
#  'greatest': 6,
#  'brand': 6,
#  'later': 6,
#  'track': 6,
#  'space': 6,
#  'pool': 6,
#  'oil': 6,
#  'stuck': 6,
#  'soul': 6,
#  'decide': 6,
#  'bigot': 6,
#  'hillary': 6,
#  'papa': 6,
#  'finished': 6,
#  'totally': 6,
#  'double': 6,
#  'leaders': 6,
#  'stress': 6,
#  'worse': 6,
#  'remains': 6,
#  'career': 6,
#  'customer': 6,
#  'hold': 6,
#  'wellness': 6,
#  'motivated': 6,
#  'spent': 6,
#  'history': 6,
#  'issue': 6,
#  'released': 6,
#  'ass': 6,
#  'photography': 6,
#  'repost': 6,
#  'accepted': 6,
#  'official': 6,
#  'stronger': 6,
#  'wake': 6,
#  'teeth': 6,
#  'pissed': 6,
#  'chick': 6,
#  'finding': 6,
#  'ice': 6,
#  'given': 6,
#  'fully': 6,
#  'celebrating': 6,
#  'gotta': 6,
#  'summeime': 6,
#  'reality': 6,
#  'teacher': 6,
#  'africa': 6,
#  'legend': 6,
#  'opinion': 6,
#  'pets': 6,
#  'ride': 6,
#  'either': 6,
#  'stories': 6,
#  'quack': 6,
#  'chill': 6,
#  'walking': 6,
#  'students': 6,
#  'felt': 6,
#  'terrorists': 6,
#  'inside': 6,
#  'outside': 6,
#  'massacre': 6,
#  'album': 6,
#  'trying': 6,
#  'upset': 6,
#  'pictures': 6,
#  'toddler': 6,
#  'due': 6,
#  'fail': 6,
#  'hockey': 6,
#  'dreams': 6,
#  'ignorance': 6,
#  'yrs': 6,
#  'therapy': 6,
#  'memes': 6,
#  'australia': 6,
#  'heard': 6,
#  'signed': 6,
#  'met': 6,
#  'inshot': 6,
#  'youll': 6,
#  'moving': 6,
#  'rose': 6,
#  'bag': 6,
#  'despite': 6,
#  'lighttherapy': 6,
#  'received': 6,
#  'graduation': 6,
#  'late': 5,
#  'packing': 5,
#  'delayed': 5,
#  'nearly': 5,
#  'plan': 5,
#  'send': 5,
#  'romance': 5,
#  'girlfriend': 5,
#  'laws': 5,
#  'drops': 5,
#  'chance': 5,
#  'build': 5,
#  'worst': 5,
#  'likely': 5,
#  'heabreaking': 5,
#  'theyre': 5,
#  'okay': 5,
#  'fantastic': 5,
#  'germany': 5,
#  'rape': 5,
#  'lyrics': 5,
#  'kitchen': 5,
#  ...}

# %%
nube_de_palabras(palabras_unidas)

# %% [markdown]
# Definimos un extractor de features donde verificamos si una palabra está presente en un tweet

# %%
def extraer_caracteristicas(tweet): 
    tweet_palabras = set(tweet)
    caracteristicas = {}
    for palabra in frecuencia:
        caracteristicas['existe(%s)' % palabra] = (palabra in tweet_palabras)
    return caracteristicas

# %% [markdown]
# Utilizamos la función nltk.classify.apply_features que retorna un objeto que actúa como una lista pero consume menos memoria.
#
# Utilizaremos esta función y luego entrenaremos nuestro clasificador bayesiano ingenuo.

# %%
# Entrenamiento 
training_set = nltk.classify.apply_features(extraer_caracteristicas,tweets_train)
clasificador = nltk.NaiveBayesClassifier.train(training_set)

# %%
# Visualizamos un elemento del set de entrenamiento. 
# Para cada palabra del conjunto de todas las palabras, se indica si el tweet la contiene o no, y además si está asociado
# a un contenido racista/sexista o no
training_set[0]
# Out:
# ({'existe(user)': False,
#   'existe(love)': False,
#   'existe(day)': False,
#   'existe(happy)': False,
#   'existe(amp)': False,
#   'existe(life)': False,
#   'existe(today)': False,
#   'existe(time)': False,
#   'existe(like)': False,
#   'existe(bihday)': False,
#   'existe(positive)': False,
#   'existe(new)': False,
#   'existe(thankful)': False,
#   'existe(people)': True,
#   'existe(one)': False,
#   'existe(good)': True,
#   'existe(get)': True,
#   'existe(fathers)': False,
#   'existe(see)': False,
#   'existe(dont)': False,
#   'existe(cant)': False,
#   'existe(smile)': False,
#   'existe(take)': False,
#   'existe(way)': False,
#   'existe(weekend)': False,
#   'existe(fun)': False,
#   'existe(work)': False,
#   'existe(want)': False,
#   'existe(healthy)': False,
#   'existe(summer)': False,
#   'existe(bull)': False,
#   'existe(family)': False,
#   'existe(friends)': False,
#   'existe(friday)': False,
#   'existe(best)': False,
#   'existe(got)': False,
#   'existe(happiness)': False,
#   'existe(days)': False,
#   'existe(back)': False,
#   'existe(make)': False,
#   'existe(first)': False,
#   'existe(beautiful)': False,
#   'existe(going)': False,
#   'existe(blog)': False,
#   'existe(really)': False,
#   'existe(music)': False,
#   'existe(ready)': False,
#   'existe(tomorrow)': False,
#   'existe(world)': False,
#   'existe(week)': False,
#   'existe(sad)': False,
#   'existe(need)': False,
#   'existe(wait)': False,
#   'existe(fathersday)': False,
#   'existe(great)': False,
#   'existe(always)': True,
#   'existe(affirmation)': False,
#   'existe(orlando)': False,
#   'existe(think)': True,
#   'existe(right)': False,
#   'existe(silver)': False,
#   'existe(model)': False,
#   'existe(morning)': False,
#   'existe(sunday)': False,
#   'existe(gold)': False,
#   'existe(never)': False,
#   'existe(much)': False,
#   'existe(know)': False,
#   'existe(home)': False,
#   'existe(finally)': False,
#   'existe(dad)': False,
#   'existe(feel)': False,
#   'existe(find)': False,
#   'existe(girl)': False,
#   'existe(next)': False,
#   'existe(cute)': False,
#   'existe(forex)': False,
#   'existe(well)': False,
#   'existe(i_am)': False,
#   'existe(say)': True,
#   'existe(things)': False,
#   'existe(youre)': False,
#   'existe(trump)': False,
#   'existe(show)': False,
#   'existe(night)': False,
#   'existe(live)': False,
#   'existe(girls)': False,
#   'existe(last)': False,
#   'existe(little)': False,
#   'existe(makes)': False,
#   'existe(year)': False,
#   'existe(amazing)': False,
#   'existe(another)': False,
#   'existe(hope)': False,
#   'existe(blessed)': False,
#   'existe(getting)': False,
#   'existe(even)': False,
#   'existe(feeling)': False,
#   'existe(old)': False,
#   'existe(thank)': False,
#   'existe(looking)': False,
#   'existe(many)': False,
#   'existe(man)': False,
#   'existe(sun)': False,
#   'existe(still)': False,
#   'existe(via)': False,
#   'existe(altwaystoheal)': False,
#   'existe(enjoy)': False,
#   'existe(sta)': False,
#   'existe(tonight)': False,
#   'existe(game)': False,
#   'existe(ever)': False,
#   'existe(come)': False,
#   'existe(hate)': False,
#   'existe(buffalo)': False,
#   'existe(would)': False,
#   'existe(may)': False,
#   'existe(yes)': False,
#   'existe(follow)': False,
#   'existe(look)': False,
#   'existe(2016)': False,
#   'existe(better)': False,
#   'existe(climb)': False,
#   'existe(bear)': False,
#   'existe(made)': False,
#   'existe(thanks)': False,
#   'existe(years)': False,
#   'existe(dog)': False,
#   'existe(might)': False,
#   'existe(selfie)': False,
#   'existe(pay)': False,
#   'existe(friend)': False,
#   'existe(free)': False,
#   'existe(soon)': False,
#   'existe(whatever)': False,
#   'existe(quote)': False,
#   'existe(cool)': False,
#   'existe(peace)': False,
#   'existe(awesome)': False,
#   'existe(hea)': True,
#   'existe(school)': False,
#   'existe(nothing)': False,
#   'existe(everyone)': False,
#   'existe(video)': False,
#   'existe(lost)': False,
#   'existe(watch)': False,
#   'existe(father)': False,
#   'existe(stop)': False,
#   'existe(saturday)': False,
#   'existe(end)': False,
#   'existe(motivation)': False,
#   'existe(guys)': False,
#   'existe(around)': False,
#   'existe(polar)': False,
#   'existe(coming)': False,
#   'existe(excited)': False,
#   'existe(every)': False,
#   'existe(believe)': False,
#   'existe(two)': False,
#   'existe(ive)': False,
#   'existe(food)': False,
#   'existe(without)': False,
#   'existe(strong)': False,
#   'existe(monday)': False,
#   'existe(white)': False,
#   'existe(city)': False,
#   'existe(baby)': False,
#   'existe(thats)': False,
#   'existe(beach)': False,
#   'existe(proud)': False,
#   'existe(house)': False,
#   'existe(bad)': False,
#   'existe(away)': False,
#   'existe(children)': False,
#   'existe(god)': False,
#   'existe(found)': False,
#   'existe(playing)': False,
#   'existe(didnt)': False,
#   'existe(dads)': False,
#   'existe(kids)': False,
#   'existe(dominate)': False,
#   'existe(direct)': False,
#   'existe(wedding)': False,
#   'existe(lol)': False,
#   'existe(travel)': False,
#   'existe(let)': False,
#   'existe(healing)': False,
#   'existe(news)': False,
#   'existe(black)': False,
#   'existe(angry)': False,
#   'existe(holiday)': False,
#   'existe(funny)': False,
#   'existe(nice)': False,
#   'existe(long)': False,
#   'existe(weeks)': False,
#   'existe(keep)': False,
#   'existe(lt3)': False,
#   'existe(something)': False,
#   'existe(thing)': False,
#   'existe(young)': False,
#   'existe(big)': False,
#   'existe(gonna)': False,
#   'existe(play)': False,
#   'existe(instagood)': False,
#   'existe(power)': False,
#   'existe(fashion)': False,
#   'existe(sex)': False,
#   'existe(doesnt)': False,
#   'existe(yeah)': False,
#   'existe(hot)': False,
#   'existe(looks)': False,
#   'existe(attack)': False,
#   'existe(help)': False,
#   'existe(check)': False,
#   'existe(boy)': False,
#   'existe(dance)': False,
#   'existe(waiting)': False,
#   'existe(money)': False,
#   'existe(women)': False,
#   'existe(everything)': False,
#   'existe(give)': False,
#   'existe(daddy)': False,
#   'existe(twitter)': False,
#   'existe(inspiration)': False,
#   'existe(song)': False,
#   'existe(left)': False,
#   'existe(making)': False,
#   'existe(true)': False,
#   'existe(grateful)': False,
#   'existe(quotes)': False,
#   'existe(joy)': False,
#   'existe(porn)': False,
#   'existe(rip)': False,
#   'existe(wonderful)': False,
#   'existe(someone)': False,
#   'existe(mindset)': False,
#   'existe(watching)': False,
#   'existe(wish)': False,
#   'existe(dogs)': False,
#   'existe(done)': False,
#   'existe(america)': False,
#   'existe(season)': False,
#   'existe(place)': False,
#   'existe(libtard)': False,
#   'existe(health)': False,
#   'existe(forward)': False,
#   'existe(leave)': False,
#   'existe(sexy)': False,
#   'existe(hour)': False,
#   'existe(use)': False,
#   'existe(fans)': False,
#   'existe(moment)': False,
#   'existe(team)': False,
#   'existe(person)': False,
#   'existe(racing)': False,
#   'existe(living)': False,
#   'existe(please)': False,
#   'existe(till)': False,
#   'existe(anyone)': False,
#   'existe(simulation)': False,
#   'existe(says)': False,
#   'existe(isnt)': False,
#   'existe(daily)': False,
#   'existe(snapchat)': False,
#   'existe(talk)': False,
#   'existe(wont)': False,
#   'existe(miss)': False,
#   'existe(future)': False,
#   'existe(crazy)': False,
#   'existe(face)': False,
#   'existe(fan)': False,
#   'existe(lovely)': False,
#   'existe(date)': False,
#   'existe(loved)': False,
#   'existe(ill)': False,
#   'existe(gay)': False,
#   'existe(goes)': False,
#   'existe(lets)': False,
#   'existe(head)': False,
#   'existe(followme)': False,
#   'existe(hair)': False,
#   'existe(photo)': False,
#   'existe(guy)': False,
#   'existe(racist)': False,
#   'existe(woman)': False,
#   'existe(job)': False,
#   'existe(tweets)': False,
#   'existe(truth)': False,
#   'existe(business)': False,
#   'existe(bing)': False,
#   'existe(bong)': False,
#   'existe(couple)': False,
#   'existe(forever)': False,
#   'existe(success)': False,
#   'existe(usa)': False,
#   'existe(yay)': False,
#   'existe(london)': False,
#   'existe(daughter)': False,
#   'existe(tbt)': False,
#   'existe(put)': False,
#   'existe(gets)': False,
#   'existe(real)': False,
#   'existe(conference)': False,
#   'existe(shop)': False,
#   'existe(mom)': False,
#   'existe(month)': False,
#   'existe(already)': False,
#   'existe(story)': False,
#   'existe(change)': False,
#   'existe(june)': False,
#   'existe(stay)': False,
#   'existe(could)': False,
#   'existe(book)': False,
#   'existe(vote)': False,
#   'existe(training)': False,
#   'existe(omg)': False,
#   'existe(cold)': False,
#   'existe(trip)': False,
#   'existe(politics)': False,
#   'existe(education)': False,
#   'existe(try)': False,
#   'existe(mind)': False,
#   'existe(freedom)': False,
#   'existe(become)': False,
#   'existe(talking)': False,
#   'existe(full)': False,
#   'existe(men)': False,
#   'existe(remember)': False,
#   'existe(son)': False,
#   'existe(also)': False,
#   'existe(loving)': False,
#   'existe(obama)': False,
#   'existe(shit)': False,
#   'existe(mood)': False,
#   'existe(tell)': False,
#   'existe(meet)': False,
#   'existe(color)': False,
#   'existe(kid)': False,
#   'existe(sweet)': False,
#   'existe(alone)': False,
#   'existe(hello)': False,
#   'existe(favorite)': False,
#   'existe(delete)': False,
#   'existe(useful)': False,
#   'existe(deletetweets)': False,
#   'existe(football)': False,
#   'existe(relax)': False,
#   'existe(lot)': False,
#   'existe(seeing)': False,
#   'existe(open)': False,
#   'existe(gun)': False,
#   'existe(control)': False,
#   'existe(else)': False,
#   'existe(hours)': False,
#   'existe(gone)': False,
#   'existe(car)': False,
#   'existe(hit)': False,
#   'existe(vacation)': False,
#   'existe(actually)': False,
#   'existe(care)': False,
#   'existe(race)': False,
#   'existe(film)': False,
#   'existe(homes)': False,
#   'existe(high)': False,
#   'existe(nyc)': False,
#   'existe(yet)': False,
#   'existe(half)': False,
#   'existe(euro2016)': False,
#   'existe(since)': False,
#   'existe(win)': False,
#   'existe(hes)': False,
#   'existe(hear)': False,
#   'existe(close)': False,
#   'existe(poetry)': False,
#   'existe(came)': False,
#   'existe(call)': False,
#   'existe(depression)': False,
#   'existe(pretty)': False,
#   'existe(complete)': False,
#   'existe(fitness)': False,
#   'existe(needs)': False,
#   'existe(wow)': False,
#   'existe(liberal)': False,
#   'existe(sorry)': False,
#   'existe(said)': False,
#   'existe(anymore)': False,
#   'existe(others)': False,
#   'existe(buy)': False,
#   'existe(empty)': False,
#   'existe(kill)': False,
#   'existe(word)': False,
#   'existe(photooftheday)': False,
#   'existe(almost)': False,
#   'existe(cat)': False,
#   'existe(vicinity)': False,
#   'existe(dream)': False,
#   'existe(sick)': False,
#   'existe(guess)': False,
#   'existe(hard)': False,
#   'existe(suppoers)': False,
#   'existe(share)': False,
#   'existe(join)': False,
#   'existe(flowers)': False,
#   'existe(heal)': False,
#   'existe(body)': False,
#   'existe(poor)': False,
#   'existe(rest)': False,
#   'existe(bday)': False,
#   'existe(tired)': False,
#   'existe(red)': False,
#   'existe(comes)': False,
#   'existe(bed)': False,
#   'existe(perfect)': False,
#   'existe(enough)': False,
#   'existe(dinner)': False,
#   'existe(target)': False,
#   'existe(months)': False,
#   'existe(thought)': False,
#   'existe(app)': False,
#   'existe(places)': False,
#   'existe(gave)': False,
#   'existe(sunny)': False,
#   'existe(sleep)': False,
#   'existe(arrived)': False,
#   'existe(read)': False,
#   'existe(bring)': False,
#   'existe(oitnb)': False,
#   'existe(environment)': False,
#   'existe(lucky)': False,
#   'existe(beer)': False,
#   'existe(child)': False,
#   'existe(violence)': False,
#   'existe(hatred)': False,
#   'existe(shes)': False,
#   'existe(community)': False,
#   'existe(safe)': False,
#   'existe(country)': False,
#   'existe(episode)': False,
#   'existe(goodmorning)': False,
#   'existe(retweet)': False,
#   'existe(single)': False,
#   'existe(gorilla)': False,
#   'existe(whats)': False,
#   'existe(booked)': False,
#   'existe(learn)': False,
#   'existe(leads)': False,
#   'existe(dancing)': False,
#   'existe(early)': False,
#   'existe(top)': False,
#   'existe(feels)': False,
#   'existe(working)': False,
#   'existe(listen)': False,
#   'existe(media)': False,
#   'existe(moments)': False,
#   'existe(used)': False,
#   'existe(coffee)': False,
#   'existe(gift)': False,
#   'existe(police)': False,
#   'existe(latest)': False,
#   'existe(survive)': False,
#   'existe(lifestyle)': False,
#   'existe(saw)': False,
#   'existe(theres)': False,
#   'existe(broken)': False,
#   'existe(anime)': False,
#   'existe(saying)': False,
#   'existe(nude)': False,
#   'existe(killed)': False,
#   'existe(shooting)': False,
#   'existe(arent)': False,
#   'existe(americans)': False,
#   'existe(went)': False,
#   'existe(garden)': False,
#   'existe(mean)': False,
#   'existe(ramadan)': False,
#   'existe(hands)': False,
#   'existe(wrong)': False,
#   'existe(drinks)': False,
#   'existe(name)': False,
#   'existe(park)': False,
#   'existe(tear)': False,
#   'existe(order)': False,
#   'existe(smiling)': False,
#   'existe(sure)': False,
#   'existe(organizations)': False,
#   'existe(faith)': False,
#   'existe(families)': False,
#   'existe(stas)': False,
#   'existe(bride)': False,
#   'existe(vine)': False,
#   'existe(together)': False,
#   'existe(social)': False,
#   'existe(wants)': False,
#   'existe(fact)': False,
#   'existe(yoga)': False,
#   'existe(rain)': False,
#   'existe(words)': False,
#   'existe(ripchristina)': False,
#   'existe(videos)': False,
#   'existe(brexit)': False,
#   'existe(kind)': False,
#   'existe(missing)': False,
#   'existe(far)': False,
#   'existe(hill)': False,
#   'existe(reach)': False,
#   'existe(task)': False,
#   'existe(aww)': False,
#   'existe(reason)': False,
#   'existe(wednesday)': False,
#   'existe(sjw)': False,
#   'existe(truly)': False,
#   'existe(100)': False,
#   'existe(scared)': False,
#   'existe(sunshine)': False,
#   'existe(reading)': False,
#   'existe(suppo)': False,
#   'existe(meeting)': False,
#   'existe(respect)': False,
#   'existe(ppl)': False,
#   'existe(post)': False,
#   'existe(nervous)': False,
#   'existe(anniversary)': False,
#   'existe(fucking)': False,
#   'existe(afternoon)': False,
#   'existe(comments)': False,
#   'existe(todays)': False,
#   'existe(festival)': False,
#   'existe(anything)': False,
#   'existe(wishing)': False,
#   'existe(beauty)': False,
#   'existe(thoughts)': False,
#   'existe(room)': False,
#   'existe(simulator)': False,
#   'existe(adapt)': False,
#   'existe(dear)': False,
#   'existe(sea)': False,
#   'existe(india)': False,
#   'existe(cultureofdevelopment)': False,
#   'existe(bless)': False,
#   'existe(growth)': False,
#   'existe(bit)': False,
#   'existe(staing)': False,
#   'existe(woohoo)': False,
#   'existe(calling)': False,
#   'existe(england)': False,
#   'existe(prayfororlando)': False,
#   'existe(voice)': False,
#   'existe(fuck)': False,
#   'existe(muslim)': False,
#   'existe(disney)': False,
#   'existe(eat)': False,
#   'existe(needed)': False,
#   'existe(officially)': False,
#   'existe(times)': True,
#   'existe(mother)': False,
#   'existe(cantwait)': False,
#   'existe(club)': False,
#   'existe(hey)': False,
#   'existe(service)': False,
#   'existe(vibes)': False,
#   'existe(begin)': False,
#   'existe(couldnt)': False,
#   'existe(female)': False,
#   'existe(feelings)': False,
#   'existe(lady)': False,
#   'existe(understand)': False,
#   'existe(using)': False,
#   'existe(teen)': False,
#   'existe(wasnt)': False,
#   'existe(glad)': False,
#   'existe(though)': False,
#   'existe(apple)': False,
#   'existe(minute)': False,
#   'existe(event)': False,
#   'existe(celebrate)': False,
#   'existe(birds)': False,
#   'existe(lawofattraction)': False,
#   'existe(huge)': False,
#   'existe(lonely)': False,
#   'existe(picture)': False,
#   'existe(political)': False,
#   'existe(seems)': False,
#   'existe(less)': False,
#   'existe(shoes)': False,
#   'existe(puppy)': False,
#   'existe(happen)': False,
#   'existe(tupac)': False,
#   'existe(cannot)': False,
#   'existe(lose)': False,
#   'existe(simple)': False,
#   'existe(age)': False,
#   'existe(number)': False,
#   'existe(state)': False,
#   'existe(allahsoil)': False,
#   'existe(movie)': False,
#   'existe(christina)': False,
#   'existe(second)': False,
#   'existe(mad)': False,
#   'existe(woh)': False,
#   'existe(question)': False,
#   'existe(friendship)': False,
#   'existe(leaving)': False,
#   'existe(problem)': False,
#   'existe(like4like)': False,
#   'existe(1st)': False,
#   'existe(florida)': False,
#   'existe(ask)': False,
#   'existe(cards)': False,
#   'existe(altright)': False,
#   'existe(tragedy)': False,
#   'existe(view)': False,
#   'existe(welcome)': False,
#   'existe(super)': False,
#   'existe(depressed)': False,
#   'existe(ending)': False,
#   'existe(damn)': False,
#   'existe(weather)': False,
#   'existe(gym)': False,
#   'existe(brother)': False,
#   'existe(forget)': False,
#   'existe(whole)': False,
#   'existe(hardcore)': False,
#   'existe(yall)': False,
#   'existe(missed)': False,
#   'existe(beginning)': False,
#   'existe(flight)': False,
#   'existe(maybe)': False,
#   'existe(thursday)': False,
#   'existe(fire)': False,
#   'existe(stuff)': False,
#   'existe(folks)': False,
#   'existe(pathetic)': False,
#   'existe(ways)': False,
#   'existe(choose)': False,
#   'existe(tickets)': False,
#   'existe(sister)': False,
#   'existe(guns)': False,
#   'existe(idea)': False,
#   'existe(orlandoshooting)': False,
#   'existe(parents)': False,
#   'existe(inspirational)': False,
#   'existe(side)': False,
#   'existe(tears)': False,
#   'existe(minutes)': False,
#   'existe(nature)': False,
#   'existe(memories)': False,
#   'existe(singing)': False,
#   'existe(wine)': False,
#   'existe(instamood)': False,
#   'existe(chicago)': False,
#   'existe(style)': False,
#   'existe(design)': False,
#   'existe(creative)': False,
#   'existe(price)': False,
#   'existe(instagram)': False,
#   'existe(death)': False,
#   'existe(holidays)': False,
#   'existe(animals)': False,
#   'existe(tgif)': False,
#   'existe(south)': False,
#   'existe(dead)': False,
#   'existe(weve)': False,
#   'existe(tweet)': False,
#   'existe(ago)': False,
#   'existe(speak)': False,
#   'existe(agree)': False,
#   'existe(blue)': False,
#   'existe(science)': False,
#   'existe(instalike)': False,
#   'existe(jobs)': False,
#   'existe(lifeisgood)': False,
#   'existe(cause)': False,
#   'existe(water)': False,
#   'existe(behind)': False,
#   'existe(course)': False,
#   'existe(shows)': False,
#   'existe(save)': False,
#   'existe(wtf)': False,
#   'existe(ordered)': False,
#   'existe(july)': False,
#   'existe(wanna)': False,
#   'existe(thinking)': False,
#   'existe(lives)': False,
#   'existe(google)': False,
#   'existe(means)': False,
#   'existe(everyday)': False,
#   'existe(games)': False,
#   'existe(able)': False,
#   'existe(countdown)': False,
#   'existe(probably)': False,
#   'existe(mountains)': False,
#   'existe(positivevibes)': False,
#   'existe(smh)': False,
#   'existe(train)': False,
#   'existe(niggas)': False,
#   'existe(ireland)': False,
#   'existe(rather)': False,
#   'existe(lgbt)': False,
#   'existe(makeup)': False,
#   'existe(youve)': False,
#   'existe(victims)': False,
#   'existe(picoftheday)': False,
#   'existe(laugh)': False,
#   'existe(gbp)': False,
#   'existe(cats)': False,
#   'existe(matter)': False,
#   'existe(blur)': False,
#   'existe(alive)': False,
#   'existe(toptags)': False,
#   'existe(sign)': False,
#   'existe(small)': False,
#   'existe(nights)': False,
#   'existe(test)': False,
#   'existe(list)': False,
#   'existe(middle)': False,
#   'existe(boyfriend)': False,
#   'existe(xoxo)': False,
#   'existe(fly)': False,
#   'existe(kiss)': False,
#   'existe(europe)': False,
#   'existe(leadership)': False,
#   'existe(treat)': False,
#   'existe(happening)': False,
#   'existe(break)': False,
#   'existe(actor)': False,
#   'existe(taking)': False,
#   'existe(conce)': False,
#   'existe(mine)': False,
#   'existe(followers)': False,
#   'existe(gamer)': False,
#   'existe(president)': False,
#   'existe(bitch)': False,
#   'existe(died)': False,
#   'existe(run)': False,
#   'existe(htt)': False,
#   'existe(society)': False,
#   'existe(offer)': False,
#   'existe(bought)': False,
#   'existe(begins)': False,
#   'existe(past)': False,
#   'existe(behappy)': False,
#   'existe(affirmations)': False,
#   'existe(reasons)': False,
#   'existe(bout)': False,
#   'existe(husband)': False,
#   'existe(xxx)': False,
#   'existe(nasty)': False,
#   'existe(shy)': False,
#   'existe(california)': False,
#   'existe(remain)': False,
#   'existe(pink)': False,
#   'existe(index)': False,
#   'existe(successful)': False,
#   'existe(must)': False,
#   'existe(congrats)': False,
#   'existe(system)': False,
#   'existe(ahead)': False,
#   'existe(shopping)': False,
#   'existe(prayers)': False,
#   'existe(smiles)': False,
#   'existe(sold)': False,
#   'existe(office)': False,
#   'existe(light)': False,
#   'existe(ones)': False,
#   'existe(gaming)': False,
#   'existe(yesterday)': False,
#   'existe(loveit)': False,
#   'existe(celebration)': False,
#   'existe(nofilter)': False,
#   'existe(adventure)': False,
#   'existe(pray)': False,
#   'existe(cry)': False,
#   'existe(instead)': False,
#   'existe(cake)': False,
#   'existe(beyond)': False,
#   'existe(pop)': False,
#   'existe(japan)': False,
#   'existe(wouldnt)': False,
#   'existe(bus)': False,
#   'existe(driver)': False,
#   'existe(ibiza)': False,
#   'existe(piano)': False,
#   'existe(count)': False,
#   'existe(pulse)': False,
#   'existe(goal)': False,
#   'existe(line)': False,
#   'existe(taken)': False,
#   'existe(spend)': False,
#   'existe(review)': False,
#   'existe(positivity)': False,
#   'existe(running)': False,
#   'existe(vegan)': False,
#   'existe(cleveland)': False,
#   'existe(cavs)': False,
#   'existe(exciting)': False,
#   'existe(naked)': False,
#   'existe(tuesday)': False,
#   'existe(energy)': False,
#   'existe(schools)': False,
#   'existe(politicians)': False,
#   'existe(impoant)': False,
#   'existe(fine)': False,
#   'existe(company)': False,
#   'existe(tech)': False,
#   'existe(racism)': False,
#   'existe(point)': False,
#   'existe(area)': False,
#   'existe(chocolate)': False,
#   'existe(fear)': False,
#   'existe(enjoying)': False,
#   'existe(heading)': False,
#   'existe(binge)': False,
#   'existe(secret)': False,
#   'existe(staed)': False,
#   'existe(fast)': False,
#   'existe(fight)': False,
#   'existe(special)': False,
#   'existe(wanted)': False,
#   'existe(drink)': False,
#   'existe(asian)': False,
#   'existe(fresh)': False,
#   'existe(seen)': False,
#   'existe(present)': False,
#   'existe(shot)': False,
#   'existe(boys)': False,
#   'existe(thankyou)': False,
#   'existe(instadaily)': False,
#   'existe(series)': False,
#   'existe(hotel)': False,
#   'existe(flag)': False,
#   'existe(e32016)': False,
#   'existe(die)': False,
#   'existe(rock)': False,
#   'existe(pic)': False,
#   'existe(anxiety)': False,
#   'existe(absolutely)': False,
#   'existe(bigotry)': False,
#   'existe(ness)': False,
#   'existe(happened)': False,
#   'existe(pain)': False,
#   'existe(babies)': False,
#   'existe(comedy)': False,
#   'existe(works)': False,
#   'existe(pack)': False,
#   'existe(trust)': False,
#   'existe(biggest)': False,
#   'existe(lunch)': False,
#   'existe(delicious)': False,
#   'existe(human)': False,
#   'existe(aint)': False,
#   'existe(gop)': False,
#   'existe(pizza)': False,
#   'existe(loves)': False,
#   'existe(difficult)': False,
#   'existe(staff)': False,
#   'existe(yolo)': False,
#   'existe(emotions)': False,
#   'existe(market)': False,
#   'existe(poland)': False,
#   'existe(finish)': False,
#   'existe(donald)': False,
#   'existe(fucked)': False,
#   'existe(scotland)': False,
#   'existe(supposed)': False,
#   'existe(imagine)': False,
#   'existe(experience)': False,
#   'existe(stand)': False,
#   'existe(youtube)': False,
#   'existe(neverump)': False,
#   'existe(candidate)': False,
#   'existe(luck)': False,
#   'existe(move)': False,
#   'existe(feet)': False,
#   'existe(passion)': False,
#   'existe(hump)': False,
#   'existe(wear)': False,
#   'existe(islam)': False,
#   'existe(ladies)': False,
#   'existe(wet)': False,
#   'existe(least)': False,
#   'existe(udtapunjab)': False,
#   'existe(worry)': False,
#   'existe(interesting)': False,
#   'existe(bright)': False,
#   'existe(island)': False,
#   'existe(tragic)': False,
#   'existe(clients)': False,
#   'existe(source)': False,
#   'existe(greatest)': False,
#   'existe(brand)': False,
#   'existe(later)': False,
#   'existe(track)': False,
#   'existe(space)': False,
#   'existe(pool)': False,
#   'existe(oil)': False,
#   'existe(stuck)': False,
#   'existe(soul)': False,
#   'existe(decide)': False,
#   'existe(bigot)': False,
#   'existe(hillary)': False,
#   'existe(papa)': False,
#   'existe(finished)': False,
#   'existe(totally)': False,
#   'existe(double)': False,
#   'existe(leaders)': False,
#   'existe(stress)': False,
#   'existe(worse)': False,
#   'existe(remains)': False,
#   'existe(career)': False,
#   'existe(customer)': False,
#   'existe(hold)': False,
#   'existe(wellness)': False,
#   'existe(motivated)': False,
#   'existe(spent)': False,
#   'existe(history)': False,
#   'existe(issue)': False,
#   'existe(released)': False,
#   'existe(ass)': False,
#   'existe(photography)': False,
#   'existe(repost)': False,
#   'existe(accepted)': False,
#   'existe(official)': False,
#   'existe(stronger)': False,
#   'existe(wake)': False,
#   'existe(teeth)': False,
#   'existe(pissed)': False,
#   'existe(chick)': False,
#   'existe(finding)': False,
#   'existe(ice)': False,
#   'existe(given)': False,
#   'existe(fully)': False,
#   'existe(celebrating)': False,
#   'existe(gotta)': False,
#   'existe(summeime)': False,
#   'existe(reality)': False,
#   'existe(teacher)': False,
#   'existe(africa)': False,
#   'existe(legend)': False,
#   'existe(opinion)': False,
#   'existe(pets)': False,
#   'existe(ride)': False,
#   'existe(either)': False,
#   'existe(stories)': False,
#   'existe(quack)': False,
#   'existe(chill)': False,
#   'existe(walking)': False,
#   'existe(students)': False,
#   'existe(felt)': False,
#   'existe(terrorists)': False,
#   'existe(inside)': False,
#   'existe(outside)': False,
#   'existe(massacre)': False,
#   'existe(album)': False,
#   'existe(trying)': False,
#   'existe(upset)': False,
#   'existe(pictures)': False,
#   'existe(toddler)': False,
#   'existe(due)': False,
#   'existe(fail)': False,
#   'existe(hockey)': False,
#   'existe(dreams)': False,
#   'existe(ignorance)': False,
#   'existe(yrs)': False,
#   'existe(therapy)': False,
#   'existe(memes)': False,
#   'existe(australia)': False,
#   'existe(heard)': False,
#   'existe(signed)': False,
#   'existe(met)': False,
#   'existe(inshot)': False,
#   'existe(youll)': False,
#   'existe(moving)': False,
#   'existe(rose)': False,
#   'existe(bag)': False,
#   'existe(despite)': False,
#   'existe(lighttherapy)': False,
#   'existe(received)': False,
#   'existe(graduation)': False,
#   'existe(late)': False,
#   'existe(packing)': False,
#   'existe(delayed)': False,
#   'existe(nearly)': False,
#   'existe(plan)': False,
#   'existe(send)': False,
#   'existe(romance)': False,
#   'existe(girlfriend)': False,
#   'existe(laws)': False,
#   'existe(drops)': False,
#   'existe(chance)': False,
#   'existe(build)': False,
#   'existe(worst)': False,
#   'existe(likely)': False,
#   'existe(heabreaking)': False,
#   'existe(theyre)': False,
#   'existe(okay)': False,
#   'existe(fantastic)': False,
#   'existe(germany)': False,
#   'existe(rape)': False,
#   'existe(lyrics)': False,
#   'existe(kitchen)': False,
#   ...},
#  0)

# %% [markdown]
# ### 5) Resultados

# %%
clasificador.show_most_informative_features(5)
# Out:
# Most Informative Features
#           existe(racism) = True                1 : 0      =     58.6 : 1.0
#           existe(racist) = True                1 : 0      =     56.0 : 1.0
#            existe(bigot) = True                1 : 0      =     49.5 : 1.0
#            existe(obama) = True                1 : 0      =     48.3 : 1.0
#          existe(liberal) = True                1 : 0      =     40.5 : 1.0

# %% [markdown]
# Lectura de resultados:
# contiene(racism) = True           Positi : Negati =     57.5 : 1.0
#
# Es decir, tweets con la palabra racist tienen 57.5 más posibilidades de ser racistas/sexistas que de no serlo.

# %%
len(training_set)
# Out:
# 4250

# %%
print(nltk.classify.accuracy(clasificador, training_set[0:4250]))
# Out:
# 0.9656470588235294

# %% [markdown]
# Determinamos la precisión (accuracy) en los datos de test:

# %%
test_set = nltk.classify.apply_features(extraer_caracteristicas,tweets_test[0:1000])
print(nltk.classify.accuracy(clasificador, test_set))
# Out:
# 0.9413333333333334

# %%
# Ejemplo de uso 

input = extraer_caracteristicas("Staying at home is lovely")
clasificador.classify(input)
# Out:
# 0

# %% [markdown]
# # **2do Modelo - LSTM**
#
# Analizaremos el mismo caso de analisis de racismo/sexismo sobre los Tweets partiendo del dataset inicial luego de la limpieza, pero usando un enfoque distinto:  redes neuronales del tipo LSTM.

# %%
#Importamos las librerias adicionales para esta seccion

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, Dropout

# %%
df = pd.read_csv('tweets.csv')
df=df.iloc[:5000]

# %%
df = df[['tweet','label']]

# %%
#Palabras a minúsculas
df['tweet'] = df['tweet'].apply(lambda x: x.lower())

# %%
#Elimina todos los caracteres no alfanuméricos
df['tweet'] = df['tweet'].apply((lambda x: re.sub('[^a-zA-z0-9\s]','',x)))

# %%
#Elimina referencias a retweets (identificados por 'rt', reemplazados por espacio)
for idx,row in df.iterrows():
    row[0] = row[0].replace('rt',' ')

# %% [markdown]
# ### 1) Tokenización
#
# Utilizamos el Tokenizer para vectorizar y convertir el texto en secuencias ya que es el input necesario para la red. Usamos un máximo de 150 features.

# %%
max_features = 150

#Inicializamos el Tokenizer
tokenizer = Tokenizer(num_words=max_features, split=' ')
#Entrenamiento
tokenizer.fit_on_texts(df['tweet'].values)
#texts_to_sequences transforma el input en arrays numéricos
X = tokenizer.texts_to_sequences(df['tweet'].values)
#pads_sequences transforma las secuencias al mismo largo
X = pad_sequences(X)

# %% [markdown]
# ### 2) Armado de red neuronal

# %% [markdown]
# Se configuran parametros para este modelo

# %%
embed_dim = 115
lstm_out = 175

model = Sequential()
model.add(Embedding(max_features, embed_dim,input_length = X.shape[1]))
model.add(Dropout(0.4))
model.add(LSTM(lstm_out, dropout=0.15, recurrent_dropout=0.15))
model.add(Dense(2,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 22, 115)           17250
#
#  dropout (Dropout)           (None, 22, 115)           0
#
#  lstm (LSTM)                 (None, 175)               203700
#
#  dense (Dense)               (None, 2)                 352
#
# =================================================================
# Total params: 221,302
# Trainable params: 221,302
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 3)Entrenamiento
# La función de pérdida utilizada es categorical_crossentropy

# %%
model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])

# %% [markdown]
# Preparamos los datos para el entrenamiento (partimos del dataset original filtrado)

# %%
Y = pd.get_dummies(df['label']).values
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.15, random_state = 38)
print(X_train.shape,Y_train.shape)
print(X_test.shape,Y_test.shape)
# Out:
# (4250, 22) (4250, 2)
# (750, 22) (750, 2)

# %% [markdown]
# Entrenamos el modelo con un batch size y cantidad de epochs determinada

# %%
batch_size = 4
model.fit(X_train, Y_train, epochs = 8, batch_size=batch_size, verbose = 2, validation_data = (X_test,Y_test))
# Out:
# Epoch 1/8
# 1063/1063 - 91s - loss: 0.2450 - accuracy: 0.9301 - val_loss: 0.2003 - val_accuracy: 0.9360 - 91s/epoch - 86ms/step
# Epoch 2/8

# %% [markdown]
# ### 4) Resultados

# %%
#Tomo 150 datos para la validación y test
validacion_tamaño = 150

X_validacion = X_test[-validacion_tamaño:]
Y_validacion= Y_test[-validacion_tamaño:]
X_test = X_test[:-validacion_tamaño]
Y_test = Y_test[:-validacion_tamaño]

# %%
print(X_test.shape,Y_test.shape)
print(X_validacion.shape,Y_validacion.shape)

# %%
score,accuracy = model.evaluate(X_test, Y_test, verbose = 2, batch_size = batch_size)
print("Score: %.2f" % (score))
print("Accuracy: %.2f" % (accuracy))

# %% [markdown]
# Utilizamos el método predict para verificar si el comportamiento con los tweets de contenido racista/sexista (1) es el mismo que con no lo son (0) o si hay un sesgo en los datos.

# %%
# Seteamos las variables del ciclo for en 0 antes de correr la celda
total_unos, total_ceros, unos, ceros = 0, 0, 0, 0
for x in range(len(X_validacion)):
    
    result = model.predict(X_validacion[x].reshape(1,X_test.shape[1]),batch_size=1,verbose = 0)[0]
   
    if np.argmax(result) == np.argmax(Y_validacion[x]):
        if np.argmax(Y_validacion[x]) == 1:
            unos = unos + 1
        else:
            ceros = ceros + 1
       
    if np.argmax(Y_validacion[x]) == 1:
        total_unos = total_unos + 1
    else:
        total_ceros = total_ceros + 1

print("Proporcion de tweets racistas/sexistas", unos/total_unos*100, "%")
print("Proporcion de tweets sin contenido racista/sexista", ceros/total_ceros*100, "%")

# %% [markdown]
# # Conclusiones
#
# El accuracy alcanzado sobre el set de testeo con el modelo LSTM es similar al obtenido con el modelo de Bayes. Sin embargo cuando analizamos la prediccion del LSTM vemos que solo acierta un  8% de la label racista/sexista. Considero que lo que debe realizarse es reentrenar los modelos con un dataset balanceado para ambas etiquetas ya que hay muchos tweets etiquetados como 0 por sobre los etiquetados como 1, lo que puede provocar una tendencia a que el modelo infiera con mayor facilidad que un tweet nuevo que se analiza le corresponde la etiqueta 0.
